# %% [markdown]
# # Chicago data and simulating address-level data
#
# The Chicago data is anonymised by moving obscuring address points etc etc.
#
# - The data can be downloaded from https://catalog.data.gov/dataset/crimes-2001-to-present-398a4 (see the module docstring of `open_cp.sources.chicago`  See also https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2
# -

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import PIL

import sys, os, csv
filename = os.path.join("..", "open_cp", "sources", "chicago.csv")

# %%
with open(filename, "rt") as file:
    reader = csv.reader(file)
    print(next(reader))
    print(next(reader))
# Out:
# ['CASE#', 'DATE  OF OCCURRENCE', 'BLOCK', ' IUCR', ' PRIMARY DESCRIPTION', ' SECONDARY DESCRIPTION', ' LOCATION DESCRIPTION', 'ARREST', 'DOMESTIC', 'BEAT', 'WARD', 'FBI CD', 'X COORDINATE', 'Y COORDINATE', 'LATITUDE', 'LONGITUDE', 'LOCATION']
# ['HZ560767', '12/22/2016 02:55:00 AM', '010XX N CENTRAL PARK AVE', '4387', 'OTHER OFFENSE', 'VIOLATE ORDER OF PROTECTION', 'APARTMENT', 'N', 'Y', '1112', '27', '26', '1152189', '1906649', '41.899712716', '-87.716454159', '(41.899712716, -87.716454159)']

# %% [markdown]
# As can be seen in the screenshot below (todo: use a library to magically visualise this sort of thing!) the longitude / latitude coorindates correspond to, roughly, the centre of the 10XX block on North Central Park Avenue.
#
# Examining more examples shows that the coordinates always code to the centre of the road in question, but often _do not_ seem to correspond to the centre of the block.  This raises the interesting possibility that the coordinates actually give an accurate indication of location.

# %%
PIL.Image.open("shot1.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=496x579 at 0x7FE6734695C0>

# %%
import geopandas as gpd
